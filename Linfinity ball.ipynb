# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt


from semi_supervised_manifold_learning import *

# %load_ext autoreload
# %autoreload 2

# %%
clean_data, noisy_data = generate_concentric_rectangles(verbose = False)

plt.scatter(noisy_data[:,0],noisy_data[:,1])
plt.show()

plt.scatter(clean_data[:,0],clean_data[:,1])
plt.show()
